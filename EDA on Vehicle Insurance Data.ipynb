# %%
import numpy as np
import pandas as pd
import seaborn as sns

customerdetail = pd.read_csv('customer_details.csv')
customerpoldetail = pd.read_csv('customer_policy_details.csv')

# %% [markdown]
# # Q1. Add the column names to both datasets:

# %%
# i) Column Name for customer details table:
customerdetail.columns
# Out:
# Index(['0', '1', '2', '3', '4', '5', '6', '7'], dtype='object')

# %%
customerdetail.rename(columns={'0':'customer_id','1':'Gender','2':'age','3':'driving licence present','4':'region code','5':'previously insured','6':'vehicle age','7':'vehicle damage'})
# Out:
#         customer_id  Gender   age  driving licence present  region code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously insured vehicle age vehicle damage
# ...

# %%
customerdetail = customerdetail.rename(columns={'0':'customer_id','1':'Gender','2':'age','3':'driving licence present','4':'region code','5':'previously insured','6':'vehicle age','7':'vehicle damage'})

# %%
customerdetail.columns
# Out:
# Index(['customer_id', 'Gender', 'age', 'driving licence present',
#        'region code', 'previously insured', 'vehicle age', 'vehicle damage'],
#       dtype='object')

# %%
customerdetail.rename(columns={'0':'customer_id','1':'Gender','2':'age','3':'driving licence present','4':'region code','5':'previously insured','6':'vehicle age','7':'vehicle damage'})
# Out:
#         customer_id  Gender   age  driving licence present  region code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously insured vehicle age vehicle damage
# ...

# %%
# ii) Column Name for customer_policy table:
customerpoldetail.columns
# Out:
# Index(['0', '1', '2', '3', '4'], dtype='object')

# %%
customerpoldetail.rename(columns={'0':'customer_id','1':'annual premium (in Rs)','2':'sales channel code','3':'vintage','4':'response'})
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 0               1.0                 40454.0                26.0    217.0
# 1               2.0                 33536.0                26.0    183.0
# 2               3.0                 38294.0                26.0     27.0
# 3               4.0                 28619.0               152.0    203.0
# 4               5.0                 27496.0               152.0     39.0
# ...             ...                     ...                 ...      ...
# 381104     381105.0                 30170.0                26.0     88.0
# 381105     381106.0                 40016.0               152.0    131.0
# 381106     381107.0                 35118.0               160.0    161.0
# 381107     381108.0                 44617.0               124.0     74.0
# 381108     381109.0                 41777.0                26.0    237.0
#
#         response
# 0            1.0
# 1            0.0
# 2            1.0
# 3            0.0
# ...

# %%
customerpoldetail = customerpoldetail.rename(columns={'0':'customer_id','1':'annual premium (in Rs)','2':'sales channel code','3':'vintage','4':'response'})

# %%
customerpoldetail.columns
# Out:
# Index(['customer_id', 'annual premium (in Rs)', 'sales channel code',
#        'vintage', 'response'],
#       dtype='object')

# %% [markdown]
# # Q2. Checking and Cleaning Data Quality:

# %%
# i)  Null values
# -Generate a summary of count of all the null values column wise

customerdetail.isnull().sum()
# Out:
# customer_id                386
# Gender                     368
# age                        368
# driving licence present    393
# region code                392
# previously insured         381
# vehicle age                381
# vehicle damage             407
# dtype: int64

# %%
customerpoldetail.isnull().sum()
# Out:
# customer_id               387
# annual premium (in Rs)    346
# sales channel code        400
# vintage                   388
# response                  361
# dtype: int64

# %%
# -Drop Null values for customer_id because central tendencies for id’s is not feasible.
customerdetail = customerdetail.dropna(subset=['customer_id'])

# %%
customerpoldetail = customerpoldetail.dropna(subset=['customer_id'])

# %%
# -Replace all null values for numeric columns by mean. 
customerdetail.mean()
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_26992\1986918749.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   customerdetail.mean()
# customer_id                190548.776244
# age                            38.822788
# driving licence present         0.997868
# region code                    26.389436
# previously insured              0.458259
# dtype: float64

# %%
# -Replace all null values for numeric columns by mean. 
customerpoldetail.mean()
# Out:
# customer_id               190547.491663
# annual premium (in Rs)     30563.999774
# sales channel code           112.036687
# vintage                      154.347192
# response                       0.122526
# dtype: float64

# %%
# -Replace all null values for Categorical value by mode.
customerdetail.mode()
# Out:
#         customer_id Gender   age  driving licence present  region code  \
# 0               1.0   Male  24.0                      1.0         28.0
# 1               2.0    NaN   NaN                      NaN          NaN
# 2               3.0    NaN   NaN                      NaN          NaN
# 3               4.0    NaN   NaN                      NaN          NaN
# 4               5.0    NaN   NaN                      NaN          NaN
# ...             ...    ...   ...                      ...          ...
# 380718     381105.0    NaN   NaN                      NaN          NaN
# 380719     381106.0    NaN   NaN                      NaN          NaN
# 380720     381107.0    NaN   NaN                      NaN          NaN
# 380721     381108.0    NaN   NaN                      NaN          NaN
# 380722     381109.0    NaN   NaN                      NaN          NaN
#
#         previously insured vehicle age vehicle damage
# 0                      0.0    1-2 Year            Yes
# ...

# %%
customerpoldetail.mode()
# Out:
#         customer_id  annual premium (in Rs)  sales channel code  vintage  \
# 0               1.0                  2630.0               152.0    256.0
# 1               2.0                     NaN                 NaN      NaN
# 2               3.0                     NaN                 NaN      NaN
# 3               4.0                     NaN                 NaN      NaN
# 4               5.0                     NaN                 NaN      NaN
# ...             ...                     ...                 ...      ...
# 380717     381105.0                     NaN                 NaN      NaN
# 380718     381106.0                     NaN                 NaN      NaN
# 380719     381107.0                     NaN                 NaN      NaN
# 380720     381108.0                     NaN                 NaN      NaN
# 380721     381109.0                     NaN                 NaN      NaN
#
#         response
# 0            0.0
# 1            NaN
# 2            NaN
# 3            NaN
# ...

# %%
# ii) Outliers
# -Generate a summary of count of all the outliers column wise
# -Replace all outlier values for numeric columns by mean. 
customerdetail.describe()
# Out:
#          customer_id            age  driving licence present    region code  \
# count  380723.000000  380357.000000            380331.000000  380332.000000
# mean   190548.776244      38.822788                 0.997868      26.389436
# std    110016.805160      15.512284                 0.046128      13.230467
# min         1.000000      20.000000                 0.000000       0.000000
# 25%     95269.500000      25.000000                 1.000000      15.000000
# 50%    190543.000000      36.000000                 1.000000      28.000000
# 75%    285822.500000      49.000000                 1.000000      35.000000
# max    381109.000000      85.000000                 1.000000      52.000000
#
#        previously insured
# count       380342.000000
# mean             0.458259
# std              0.498255
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%              1.000000
# max              1.000000

# %%
customerpoldetail.describe()
# Out:
#          customer_id  annual premium (in Rs)  sales channel code  \
# count  380722.000000           380378.000000       380322.000000
# mean   190547.491663            30563.999774          112.036687
# std    110013.824148            17197.918886           54.205529
# min         1.000000             2630.000000            1.000000
# 25%     95276.250000            24407.000000           29.000000
# 50%    190536.500000            31667.000000          133.000000
# 75%    285818.750000            39401.750000          152.000000
# max    381109.000000           540165.000000          163.000000
#
#              vintage       response
# count  380334.000000  380361.000000
# mean      154.347192       0.122526
# std        83.670742       0.327892
# min        10.000000       0.000000
# 25%        82.000000       0.000000
# 50%       154.000000       0.000000
# 75%       227.000000       0.000000
# max       299.000000       1.000000

# %%
Q1 = customerdetail.quantile(0.25)
Q2 = customerdetail.quantile(0.75)
IQR = Q2-Q1
print(IQR)
# Out:
# customer_id                190553.0
# age                            24.0
# driving licence present         0.0
# region code                    20.0
# previously insured              1.0
# dtype: float64

# %%
Q1 = customerpoldetail.quantile(0.25)
Q2 = customerpoldetail.quantile(0.75)
IQR = Q2-Q1
print(IQR)
# Out:
# customer_id               190542.50
# annual premium (in Rs)     14994.75
# sales channel code           123.00
# vintage                      145.00
# response                       0.00
# dtype: float64

# %%
# iii) white spaces
# -remove white sapces
customerdetail.replace(" ")
# Out:
#         customer_id  Gender   age  driving licence present  region code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 381104     381105.0    Male  74.0                      1.0         26.0
# 381105     381106.0    Male  30.0                      1.0         37.0
# 381106     381107.0    Male  21.0                      1.0         30.0
# 381107     381108.0  Female  68.0                      1.0         14.0
# 381108     381109.0    Male  46.0                      1.0         29.0
#
#         previously insured vehicle age vehicle damage
# ...

# %% [markdown]
# # Q3. Create a Master table for future use. Join the customer table and customer_policy table to get a master table using customer_id in both tables.

# %%
master_table = pd.merge(customerdetail,customerpoldetail)
master_table
# Out:
#         customer_id  Gender   age  driving licence present  region code  \
# 0               1.0    Male  44.0                      1.0         28.0
# 1               2.0    Male  76.0                      1.0          3.0
# 2               3.0    Male  47.0                      1.0         28.0
# 3               4.0    Male  21.0                      1.0         11.0
# 4               5.0  Female  29.0                      1.0         41.0
# ...             ...     ...   ...                      ...          ...
# 380331     381105.0    Male  74.0                      1.0         26.0
# 380332     381106.0    Male  30.0                      1.0         37.0
# 380333     381107.0    Male  21.0                      1.0         30.0
# 380334     381108.0  Female  68.0                      1.0         14.0
# 380335     381109.0    Male  46.0                      1.0         29.0
#
#         previously insured vehicle age vehicle damage  annual premium (in Rs)  \
# ...

# %% [markdown]
# # Q4. Company needs some important information from the master table to make decisions for future growth.They needs following information:

# %%
# i)Gender wise average annual premium
master_table.groupby(["Gender"]).mean()["annual premium (in Rs)"]
# Out:
# Gender
# Female    30491.959528
# Male      30624.674414
# Name: annual premium (in Rs), dtype: float64

# %%
# ii)Age wise average annual premium
master_table.groupby(["age"]).mean()["annual premium (in Rs)"]
# Out:
# age
# 20.0    26920.517153
# 21.0    30564.476130
# 22.0    30824.039423
# 23.0    30688.699065
# 24.0    31184.306152
#             ...
# 81.0    31201.571429
# 82.0    37705.379310
# 83.0    31012.727273
# 84.0    35440.818182
# 85.0    29792.363636
# Name: annual premium (in Rs), Length: 66, dtype: float64

# %%
# iii)  Is your data balanced between the genders?
master_table.groupby(['Gender']).count()
# Out:
#         customer_id     age  driving licence present  region code  \
# Gender
# Female       174485  174332                   174306       174330
# Male         205484  205272                   205272       205250
#
#         previously insured  vehicle age  vehicle damage  \
# Gender
# Female              174321       174309          174300
# Male                205267       205279          205266
#
#         annual premium (in Rs)  sales channel code  vintage  response
# Gender
# Female                  174318              174284   174304    174329
# Male                    205307              205288   205277    205281

# %%
# iv) Vehicle age wise average annual premium.
master_table.groupby(["vehicle age"]).mean()["annual premium (in Rs)"]
# Out:
# vehicle age
# 1-2 Year     30522.422917
# < 1 Year     30115.361397
# > 2 Years    35661.355606
# Name: annual premium (in Rs), dtype: float64

# %% [markdown]
# # Q5. Is there any relation between Person Age and annual premium?

# %%
corrMatrix = master_table.corr()
sns.heatmap(corrMatrix, annot = True)
# Out:
# <AxesSubplot:>

# %%
df = master_table["annual premium (in Rs)"]
df
# Out:
# 0         40454.0
# 1         33536.0
# 2         38294.0
# 3         28619.0
# 4         27496.0
#            ...
# 380331    30170.0
# 380332    40016.0
# 380333    35118.0
# 380334    44617.0
# 380335    41777.0
# Name: annual premium (in Rs), Length: 380336, dtype: float64

# %%
df1 = master_table['age']
df1
# Out:
# 0         44.0
# 1         76.0
# 2         47.0
# 3         21.0
# 4         29.0
#           ...
# 380331    74.0
# 380332    30.0
# 380333    21.0
# 380334    68.0
# 380335    46.0
# Name: age, Length: 380336, dtype: float64

# %%
r = np.corrcoef(df,df1)
r
# Out:
# array([[nan, nan],
#        [nan, nan]])
